# %%
import pandas as pd

# %%
url = "https://www.espn.com/nba/standings"

def names(url):
    df = pd.read_html(url, header=None)[0]
    df = df.reset_index().T.reset_index().T
    df = df[1].reset_index(drop = True)
    temp_df = []
    for i in range(0,len(df)):
        temp_df.append(df[i][8:].split()[1:])

    temp_df = [i for j in temp_df for i in j]
    temp_df.pop(4)
    temp_df = pd.DataFrame(temp_df)

    
    return temp_df

temp_df = names(url)
temp_df
# Out:
#             0
# 0       Bucks
# 1     Celtics
# 2       76ers
# 3   Cavaliers
# 4      Knicks
# 5        Nets
# 6       Hawks
# 7        Heat
# 8       Bulls
# 9     Raptors
# 10     Pacers
# 11    Wizards
# 12      Magic
# 13    Hornets
# 14    Pistons

# %%
url = "https://www.espn.com/nba/standings"
def East(url):
    df = pd.read_html(url, header=None)[0]
    df = df.reset_index().T.reset_index().T
    df = df[1].reset_index(drop = True)
    temp_df = []
    for i in range(0,len(df)):
        temp_df.append(df[i][8:].split()[1:])

    temp_df = [i for j in temp_df for i in j]
    temp_df.remove("York")
    temp_df = pd.DataFrame(temp_df)
    df1 = pd.read_html(url, header=None)[1]
    df1
    East_standings = pd.concat([temp_df, df1], axis = "columns")
    East_standings["E/W"] = "0"
    
    return East_standings

East_Standings = East(url)
East_Standings
# Out:
#             0   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  OPP PPG  \
# 0       Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9    113.3
# 1     Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9    111.4
# 2       76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2    110.9
# 3   Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3    106.9
# 4      Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0    113.1
# 5        Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4    112.5
# 6       Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4    118.1
# 7        Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5    109.8
# 8       Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1    111.8
# 9     Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9    111.4
# 10     Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3    119.5
# ...

# %%
df1 = pd.read_html(url, header=None)[1]
df1
East_standings = pd.concat([temp_df, df1], axis = "columns")
East_standings["E/W"] = "0"
East_standings
# Out:
#             0   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  OPP PPG  \
# 0       Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9    113.3
# 1     Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9    111.4
# 2       76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2    110.9
# 3   Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3    106.9
# 4      Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0    113.1
# 5        Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4    112.5
# 6       Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4    118.1
# 7        Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5    109.8
# 8       Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1    111.8
# 9     Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9    111.4
# 10     Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3    119.5
# ...

# %%
df2 =  pd.read_html(url, header=None)[2]
df2 = df2.reset_index().T.reset_index().T
df2 = df2[1].reset_index(drop = True)
temp_df2 = []
for i in range(0,len(df2)):
    temp_df2.append(df2[i][8:].split()[1:])
    

temp_df2 = [i for j in temp_df2 for i in j]
temp_df2
# Out:
# ['Nuggets',
#  'Grizzlies',
#  'Kings',
#  'Suns',
#  'Clippers',
#  'State',
#  'Warriors',
#  'Angeles',
#  'Lakers',
#  'Timberwolves',
#  'City',
#  'Thunder',
#  'Orleans',
#  'Pelicans',
#  'Mavericks',
#  'Jazz',
#  'Trail',
#  'Blazers',
#  'Rockets',
#  'Antonio',
#  'Spurs']

# %%
temp_df2 = [elem for elem in temp_df2 if elem not in ["State","Angeles","City","Orleans","Blazers","Antonio"]]
temp_df2
#remove_indices = [5,7,10,12,17,19]
#temp_df2 = [i for j, i in enumerate(temp_df2) if j not in remove_indices]
#temp_df2
# Out:
# ['Nuggets',
#  'Grizzlies',
#  'Kings',
#  'Suns',
#  'Clippers',
#  'Warriors',
#  'Lakers',
#  'Timberwolves',
#  'Thunder',
#  'Pelicans',
#  'Mavericks',
#  'Jazz',
#  'Trail',
#  'Rockets',
#  'Spurs']

# %%
temp_df2 = pd.DataFrame(temp_df2)
temp_df2.loc[temp_df2[0] == "Trail"] = "Trailblaizers"
temp_df2
# Out:
#                 0
# 0         Nuggets
# 1       Grizzlies
# 2           Kings
# 3            Suns
# 4        Clippers
# 5        Warriors
# 6          Lakers
# 7    Timberwolves
# 8         Thunder
# 9        Pelicans
# 10      Mavericks
# 11           Jazz
# 12  Trailblaizers
# 13        Rockets
# 14          Spurs

# %%
df3 = pd.read_html(url, header=None)[3]
df3
West_standings = pd.concat([temp_df2, df3], axis = "columns")
West_standings["E/W"] = 1
West_standings
# Out:
#                 0   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0         Nuggets  53  29  0.646   -   34-7  19-22  10-6  34-18  115.8
# 1       Grizzlies  51  31  0.622   2   35-6  16-25  13-3  30-22  116.9
# 2           Kings  48  34  0.585   5  23-18  25-16   9-7  32-20  120.7
# 3            Suns  45  37  0.549   8  28-13  17-24   9-7  30-22  113.6
# 4        Clippers  44  38  0.537   9  23-18  21-20   9-7  27-25  113.6
# 5        Warriors  44  38  0.537   9   33-8  11-30   7-9  30-22  118.9
# 6          Lakers  43  39  0.524  10  23-18  20-21  6-10  27-25  117.2
# 7    Timberwolves  42  40  0.512  11  22-19  20-21   8-8  29-23  115.8
# 8         Thunder  40  42  0.488  13  24-17  16-25   9-7  25-27  117.5
# 9        Pelicans  42  40  0.512  11  27-14  15-26  11-5  29-23  114.4
# 10      Mavericks  38  44  0.463  15  23-18  15-26   9-7  28-24  114.2
# 11           Jazz  37  45  0.451  16  23-18  14-27  6-10  24-28  117.1
# ...

# %%
def West(url):
    df2 =  pd.read_html(url, header=None)[2]
    df2 = df2.reset_index().T.reset_index().T
    df2 = df2[1].reset_index(drop = True)
    temp_df2 = []
    for i in range(0,len(df2)):
        temp_df2.append(df2[i][8:].split()[1:])
    

    temp_df2 = [i for j in temp_df2 for i in j]
    temp_df2 = [elem for elem in temp_df2 if elem not in ["State","Angeles","City","Orleans","Blazers","Antonio"]]
    temp_df2 = pd.DataFrame(temp_df2)
    temp_df2.loc[temp_df2[0] == "Trail"] = "Trailblaizers"
    df3 = pd.read_html(url, header=None)[3]
    
    West_standings = pd.concat([temp_df2, df3], axis = "columns")
    West_standings["E/W"] = 1
    return West_standings

West_Standings = West(url)
West_Standings
# Out:
#                 0   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0         Nuggets  53  29  0.646   -   34-7  19-22  10-6  34-18  115.8
# 1       Grizzlies  51  31  0.622   2   35-6  16-25  13-3  30-22  116.9
# 2           Kings  48  34  0.585   5  23-18  25-16   9-7  32-20  120.7
# 3            Suns  45  37  0.549   8  28-13  17-24   9-7  30-22  113.6
# 4        Clippers  44  38  0.537   9  23-18  21-20   9-7  27-25  113.6
# 5        Warriors  44  38  0.537   9   33-8  11-30   7-9  30-22  118.9
# 6          Lakers  43  39  0.524  10  23-18  20-21  6-10  27-25  117.2
# 7    Timberwolves  42  40  0.512  11  22-19  20-21   8-8  29-23  115.8
# 8         Thunder  40  42  0.488  13  24-17  16-25   9-7  25-27  117.5
# 9        Pelicans  42  40  0.512  11  27-14  15-26  11-5  29-23  114.4
# 10      Mavericks  38  44  0.463  15  23-18  15-26   9-7  28-24  114.2
# 11           Jazz  37  45  0.451  16  23-18  14-27  6-10  24-28  117.1
# ...

# %%
Total_standings = pd.concat([East_standings,West_standings])
Total_standings.reset_index(drop = True)
Total_standings["Team"] = Total_standings[0]
Total_standings = Total_standings.drop(0, axis = 1)
cols = Total_standings.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['Team',
#  'W',
#  'L',
#  'PCT',
#  'GB',
#  'HOME',
#  'AWAY',
#  'DIV',
#  'CONF',
#  'PPG',
#  'OPP PPG',
#  'DIFF',
#  'STRK',
#  'L10',
#  'E/W']

# %%
Total_standings = Total_standings[cols]
Total_standings
# Out:
#              Team   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0           Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9
# 1         Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9
# 2           76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2
# 3       Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3
# 4          Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0
# 5            Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4
# 6           Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4
# 7            Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5
# 8           Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1
# 9         Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9
# 10         Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3
# 11        Wizards  35  47  0.427  23  19-22  16-25   8-8  21-31  113.2
# ...

# %%
Total_standings["Team"].values
# Out:
# array(['Bucks', 'Celtics', '76ers', 'Cavaliers', 'Knicks', 'Nets',
#        'Hawks', 'Heat', 'Bulls', 'Raptors', 'Pacers', 'Wizards', 'Magic',
#        'Hornets', 'Pistons', 'Nuggets', 'Grizzlies', 'Kings', 'Suns',
#        'Clippers', 'Warriors', 'Lakers', 'Timberwolves', 'Thunder',
#        'Pelicans', 'Mavericks', 'Jazz', 'Trailblaizers', 'Rockets',
#        'Spurs'], dtype=object)

# %%
def test():
    if Total_standings["Team"] in ["Raptors","Knicks"]:
        Total_standings["Division"] == "Atlantic"

def Total(East, West):
    Total_standings = pd.concat([East,West])
    Total_standings.reset_index(drop = True)
    Total_standings["Team"] = Total_standings[0]
    Total_standings = Total_standings.drop(0, axis = 1)
    cols = Total_standings.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    Total_standings = Total_standings[cols]
    division_map = {"Raptors":"Atlantic", "Nets": "Atlantic", "Knicks":"Atlantic", "Pistons":"Central", "Hornets":"Southeast","76ers":"Atlantic","Celtics":"Atlantic","Pacers":"Central","Bulls":"Central","Cavaliers":"Central","Bucks":"Central","Magic":"Southeast","Wizards":"Southeast" ,"Hawks":"Southeast","Heat":"Southeast","Trailblazers":"Northwest","Jazz":"Northwest","Thunder":"Northwest","Timberwolves":"Northwest","Nuggets":"Northwest","Lakers":"Pacific","Clippers":"Pacific","Warriors":"Pacific","Suns":"Pacific","Kings":"Pacific","Rockets":"Southwest"    ,"Spurs":"Southwest"    ,"Mavericks":"Southwest"    ,"Pelicans":"Southwest"    ,"Grizzlies":"Southwest"   }
    Total_standings["Divison"]= Total_standings["Team"].map(division_map)
 
    return Total_standings

Total(East_Standings, West_Standings)
# Out:
#              Team   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0           Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9
# 1         Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9
# 2           76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2
# 3       Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3
# 4          Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0
# 5            Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4
# 6           Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4
# 7            Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5
# 8           Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1
# 9         Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9
# 10         Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3
# 11        Wizards  35  47  0.427  23  19-22  16-25   8-8  21-31  113.2
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)
url = "https://www.espn.com/nba/standings"

def East(url):
    df = pd.read_html(url, header=None)[0]
    df = df.reset_index().T.reset_index().T
    df = df[1].reset_index(drop = True)
    temp_df = []
    for i in range(0,len(df)):
        temp_df.append(df[i][4:].split()[1:])

    temp_df = [i for j in temp_df for i in j]
    temp_df = [elem for elem in temp_df if elem not in ["York"]]
    temp_df = pd.DataFrame(temp_df)
    df1 = pd.read_html(url, header=None)[1]
    df1
    East_standings = pd.concat([temp_df, df1], axis = "columns")
    East_standings["E/W"] = "0"
    
    return East_standings

def West(url):
    df2 =  pd.read_html(url, header=None)[2]
    df2 = df2.reset_index().T.reset_index().T
    df2 = df2[1].reset_index(drop = True)
    temp_df2 = []
    for i in range(0,len(df2)):
        temp_df2.append(df2[i][4:].split()[1:])
    

    temp_df2 = [i for j in temp_df2 for i in j]
    temp_df2 = [elem for elem in temp_df2 if elem not in ["State","Angeles","City","Orleans","Blazers","Antonio"]]
    temp_df2 = pd.DataFrame(temp_df2)
    temp_df2.loc[temp_df2[0] == "Trail"] = "Trailblazers"

    df3 = pd.read_html(url, header=None)[3]
    
    West_standings = pd.concat([temp_df2, df3], axis = "columns")
    West_standings["E/W"] = 1
    return West_standings

def Total(East, West):
    Total_standings = pd.concat([East,West])
    Total_standings.reset_index(drop = True)
    Total_standings["Team"] = Total_standings[0]
    Total_standings = Total_standings.drop(0, axis = 1)
    cols = Total_standings.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    Total_standings = Total_standings[cols]
    division_map = {"Raptors":"Atlantic", "Nets": "Atlantic", "Knicks":"Atlantic", "Pistons":"Central", "Hornets":"Southeast","76ers":"Atlantic","Celtics":"Atlantic","Pacers":"Central","Bulls":"Central","Cavaliers":"Central","Bucks":"Central","Magic":"Southeast","Wizards":"Southeast" ,"Hawks":"Southeast","Heat":"Southeast","Trailblazers":"Northwest","Jazz":"Northwest","Thunder":"Northwest","Timberwolves":"Northwest","Nuggets":"Northwest","Lakers":"Pacific","Clippers":"Pacific","Warriors":"Pacific","Suns":"Pacific","Kings":"Pacific","Rockets":"Southwest"    ,"Spurs":"Southwest"    ,"Mavericks":"Southwest"    ,"Pelicans":"Southwest", "Bobcats":"Southeast","Grizzlies":"Southwest"   }
    Total_standings["Divison"]= Total_standings["Team"].map(division_map)
 
    return Total_standings


def Standings(url):
    East_Standings = East(url)
    West_Standings = West(url)
    Total_Standings = Total(East_Standings, West_Standings)
    Total_Standings["Year"] = "2023"
    return Total_Standings

TS = Standings(url)
TS
# Out:
#             Team   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0          Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9
# 1        Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9
# 2          76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2
# 3      Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3
# 4         Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0
# 5           Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4
# 6          Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4
# 7           Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5
# 8          Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1
# 9        Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9
# 10        Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3
# 11       Wizards  35  47  0.427  23  19-22  16-25   8-8  21-31  113.2
# ...

# %%
url2022 = "https://www.espn.com/nba/standings/_/sort/gamesbehind/dir/desc/season/2022"
def Standings(url):
    East_Standings = East(url)
    West_Standings = West(url)
    Total_Standings = Total(East_Standings, West_Standings)
    Total_Standings["Year"] = "2022"
    return Total_Standings

TS2022 = Standings(url2022)
TS2022
# Out:
#             Team   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0          Magic  22  60  0.268  31  12-29  10-31  3-13  12-40  104.2
# 1        Pistons  23  59  0.280  30  13-28  10-31  6-10  18-34  104.8
# 2         Pacers  25  57  0.305  28  16-25   9-32  2-14  11-41  111.5
# 3        Wizards  35  47  0.427  18  21-20  14-27   7-9  24-28  108.6
# 4         Knicks  37  45  0.451  16  17-24  20-21  5-11  22-30  106.5
# 5          Hawks  43  39  0.524  10  27-14  16-25   9-7  26-26  113.9
# 6        Hornets  43  39  0.524  10  22-19  21-20   8-8  27-25  115.3
# 7           Nets  44  38  0.537   9  20-21  24-17  10-6  31-21  112.9
# 8      Cavaliers  44  38  0.537   9  25-16  19-22  10-6  27-25  107.8
# 9          Bulls  46  36  0.561   7  27-14  19-22  10-6  29-23  111.6
# 10       Raptors  48  34  0.585   5  24-17  24-17  10-6  30-22  109.4
# 11       Celtics  51  31  0.622   2  28-13  23-18   9-7  33-19  111.8
# ...

# %%
pd.concat([TS, TS2022], axis = 0)
# Out:
#             Team   W   L    PCT  GB   HOME   AWAY   DIV   CONF    PPG  \
# 0          Bucks  58  24  0.707   -   32-9  26-15  11-5  35-17  116.9
# 1        Celtics  57  25  0.695   1   32-9  25-16  11-5  34-18  117.9
# 2          76ers  54  28  0.659   4  29-12  25-16  10-6  34-18  115.2
# 3      Cavaliers  51  31  0.622   7  31-10  20-21  13-3  34-18  112.3
# 4         Knicks  47  35  0.573  11  23-18  24-17   8-8  32-20  116.0
# 5           Nets  45  37  0.549  13  23-18  22-19   7-9  30-22  113.4
# 6          Hawks  41  41  0.500  17  24-17  17-24   8-8  26-26  118.4
# 7           Heat  44  38  0.537  14  27-14  17-24  10-6  24-28  109.5
# 8          Bulls  40  42  0.488  18  22-19  18-23   7-9  27-25  113.1
# 9        Raptors  41  41  0.500  17  27-14  14-27  4-12  26-26  112.9
# 10        Pacers  35  47  0.427  23  20-21  15-26   7-9  24-28  116.3
# 11       Wizards  35  47  0.427  23  19-22  16-25   8-8  21-31  113.2
# ...

# %%
urls = ["https://www.espn.com/nba/standings/_/sort/gamesbehind/dir/desc/season/"+str(k) for k in range(2022,2012,-1)]  
urls

def Year_Standings(url):
    East_Standings = East(url)
    West_Standings = West(url)
    Total_Standings = Total(East_Standings, West_Standings)
    Total_Standings["Year"] = url[70:]
    return Total_Standings

final_df = pd.DataFrame()
for url in urls:
    final_df = pd.concat([final_df, Year_Standings(url)], axis = 0)

final_df.reset_index().T.reset_index().T
final_df.reset_index(drop = True)
final_df = pd.concat([TS, final_df], axis = 0)
final_df = final_df.reset_index(drop = True)
final_df
# Out:
#             Team   W   L    PCT    GB   HOME   AWAY   DIV   CONF    PPG  \
# 0          Bucks  58  24  0.707     -   32-9  26-15  11-5  35-17  116.9
# 1        Celtics  57  25  0.695     1   32-9  25-16  11-5  34-18  117.9
# 2          76ers  54  28  0.659     4  29-12  25-16  10-6  34-18  115.2
# 3      Cavaliers  51  31  0.622     7  31-10  20-21  13-3  34-18  112.3
# 4         Knicks  47  35  0.573    11  23-18  24-17   8-8  32-20  116.0
# 5           Nets  45  37  0.549    13  23-18  22-19   7-9  30-22  113.4
# 6          Hawks  41  41  0.500    17  24-17  17-24   8-8  26-26  118.4
# 7           Heat  44  38  0.537    14  27-14  17-24  10-6  24-28  109.5
# 8          Bulls  40  42  0.488    18  22-19  18-23   7-9  27-25  113.1
# 9        Raptors  41  41  0.500    17  27-14  14-27  4-12  26-26  112.9
# 10        Pacers  35  47  0.427    23  20-21  15-26   7-9  24-28  116.3
# 11       Wizards  35  47  0.427    23  19-22  16-25   8-8  21-31  113.2
# ...

# %%
#final_df.to_excel("NBA_W_Years.xlsx")

# %%
def remove_positions(df):
    '''Removes The position indicator after each player's name (i.e. PG, PF, SG), also drops the "Total" row as it's not needed.'''
    words = []
    for i in df["Name"]:
        words.append(i.split()[0:2])
    words = pd.DataFrame(words)
    words.columns = ["First","Last"]
    words["Names"] = words['First']+" "+ words["Last"]
    words = words.drop("First", axis = 1).drop("Last", axis = 1)
    df["Name"] = words
    #df = df.drop(16)
    df = df.dropna().reset_index().drop("index", axis = "columns")
    return df

players_df_shoot = pd.DataFrame()
url = "https://www.espn.com/nba/team/stats/_/name/den/denver-nuggets"
player_names = pd.read_html(url)[0]
player_shoot = pd.read_html(url)[3]
player_concat = pd.concat([player_names,player_shoot],axis = "columns")
    
players_df_shoot = pd.concat([players_df_shoot, player_concat], ignore_index = True)

remove_positions(players_df_shoot)
#Cleaned up dataframe with all player stats in western conference
players_df_shoot
# Out:
#                         Name   FGM   FGA   FG%   3PM   3PA    3P%   FTM   FTA  \
# 0               Nikola Jokic   9.4  14.8  63.2   0.8   2.2   38.3   4.9   6.0
# 1               Jamal Murray   7.3  16.0  45.4   2.6   6.6   39.8   2.8   3.3
# 2             Michael Porter   6.4  13.2  48.7   3.0   7.3   41.4   1.5   1.9
# 3               Aaron Gordon   6.3  11.2  56.4   0.9   2.5   34.7   2.8   4.6
# 4               Bones Hyland   4.1  10.3  39.9   2.2   5.7   37.8   1.7   2.0
# 5                Bruce Brown   4.5   9.3  48.3   1.1   3.2   35.8   1.5   1.9
# 6   Kentavious Caldwell-Pope   3.8   8.3  46.2   1.8   4.2   42.3   1.4   1.6
# 7             Reggie Jackson   3.1   8.0  38.3   1.2   4.3   27.9   0.6   0.8
# 8                 Jeff Green   2.9   5.9  48.8   0.5   1.9   28.8   1.6   2.1
# 9                 Zeke Nnaji   2.1   3.7  56.1   0.3   1.2   26.2   0.8   1.2
# 10            DeAndre Jordan   2.3   2.9  76.5   0.0   0.0  100.0   0.6   1.2
# ...

# %%
players_df = pd.DataFrame()
player_names = pd.read_html(url)[0]
player_stats = pd.read_html(url)[1]
player_concat = pd.concat([player_names,player_stats],axis = "columns")
players_df = pd.concat([players_df, player_concat], ignore_index = True)

remove_positions(players_df)
#Cleaned up dataframe with all player stats in western conference
pd.set_option('display.max_rows', None)
players_df

N_df = pd.merge(players_df, players_df_shoot, on = "Name")
N_df = N_df.drop(18)

# %%
N_df
# Out:
#                         Name  GP    GS   MIN   PTS   OR   DR   REB  AST  STL  \
# 0               Nikola Jokic  69  69.0  33.7  24.5  2.4  9.4  11.8  9.8  1.3
# 1               Jamal Murray  65  65.0  32.8  20.0  0.7  3.2   4.0  6.2  1.0
# 2             Michael Porter  62  62.0  29.0  17.4  1.0  4.5   5.5  1.0  0.6
# 3               Aaron Gordon  68  68.0  30.2  16.3  2.4  4.1   6.6  3.0  0.8
# 4               Bones Hyland  42   1.0  19.5  12.1  0.2  1.8   2.0  3.0  0.7
# 5                Bruce Brown  80  31.0  28.5  11.5  0.8  3.3   4.1  3.4  1.1
# 6   Kentavious Caldwell-Pope  76  76.0  31.3  10.8  0.5  2.3   2.7  2.4  1.5
# 7             Reggie Jackson  16   2.0  19.9   7.9  0.2  1.6   1.8  3.1  0.6
# 8                 Jeff Green  56   4.0  19.5   7.8  0.7  1.9   2.6  1.2  0.3
# 9                 Zeke Nnaji  53   5.0  13.7   5.2  1.2  1.4   2.6  0.3  0.3
# 10            DeAndre Jordan  39   8.0  15.0   5.1  1.3  3.8   5.2  0.9  0.3
# ...

# %%
pd.set_option('display.max_rows', None)

def gen_dataframe(url):
    players_df = pd.DataFrame()
    player_names = pd.read_html(url)[0]
    player_stats = pd.read_html(url)[1]
    player_concat = pd.concat([player_names,player_stats],axis = "columns")
    players_df = pd.concat([players_df, player_concat], ignore_index = True)
    remove_positions(players_df)



    players_df_shoot = pd.DataFrame()
    
    player_names = pd.read_html(url)[0]
    player_shoot = pd.read_html(url)[3]
    player_concat = pd.concat([player_names,player_shoot],axis = "columns")
    
    players_df_shoot = pd.concat([players_df_shoot, player_concat], ignore_index = True)

    remove_positions(players_df_shoot)



    final_df = pd.merge(players_df, players_df_shoot, on = "Name")
    final_df["Team"] = url.split("-")[-1].capitalize()
    
    return final_df

# %%
Nuggets = gen_dataframe("https://www.espn.com/nba/team/stats/_/name/den/denver-nuggets")
Nuggets
# Out:
#                         Name  GP    GS   MIN    PTS    OR    DR   REB   AST  \
# 0               Nikola Jokic  69  69.0  33.7   24.5   2.4   9.4  11.8   9.8
# 1               Jamal Murray  65  65.0  32.8   20.0   0.7   3.2   4.0   6.2
# 2             Michael Porter  62  62.0  29.0   17.4   1.0   4.5   5.5   1.0
# 3               Aaron Gordon  68  68.0  30.2   16.3   2.4   4.1   6.6   3.0
# 4               Bones Hyland  42   1.0  19.5   12.1   0.2   1.8   2.0   3.0
# 5                Bruce Brown  80  31.0  28.5   11.5   0.8   3.3   4.1   3.4
# 6   Kentavious Caldwell-Pope  76  76.0  31.3   10.8   0.5   2.3   2.7   2.4
# 7             Reggie Jackson  16   2.0  19.9    7.9   0.2   1.6   1.8   3.1
# 8                 Jeff Green  56   4.0  19.5    7.8   0.7   1.9   2.6   1.2
# 9                 Zeke Nnaji  53   5.0  13.7    5.2   1.2   1.4   2.6   0.3
# 10            DeAndre Jordan  39   8.0  15.0    5.1   1.3   3.8   5.2   0.9
# ...

# %%
Warriors = gen_dataframe("https://www.espn.com/nba/team/stats/_/name/gs/golden-state-warriors")
Warriors
# Out:
#                 Name  GP    GS   MIN    PTS    OR    DR   REB   AST  STL  BLK  \
# 0      Stephen Curry  56  56.0  34.7   29.4   0.7   5.4   6.1   6.3  0.9  0.4
# 1      Klay Thompson  69  69.0  33.0   21.9   0.6   3.6   4.1   2.4  0.7  0.4
# 2       Jordan Poole  82  43.0  30.0   20.4   0.4   2.4   2.7   4.5  0.8  0.3
# 3     Andrew Wiggins  37  37.0  32.2   17.1   1.6   3.4   5.0   2.3  1.2  0.8
# 4   Jonathan Kuminga  67  16.0  20.8    9.9   1.0   2.4   3.4   1.9  0.6  0.5
# 5   Donte DiVincenzo  72  36.0  26.3    9.4   1.1   3.4   4.5   3.5  1.3  0.1
# 6     Draymond Green  73  73.0  31.5    8.5   0.9   6.3   7.2   6.8  1.0  0.8
# 7       Kevon Looney  82  70.0  23.9    7.0   3.3   5.9   9.3   2.5  0.6  0.6
# 8      James Wiseman  21   0.0  12.5    6.9   0.9   2.6   3.5   0.7  0.1  0.3
# 9          Ty Jerome  45   2.0  18.1    6.9   0.2   1.6   1.7   3.0  0.5  0.1
# 10      Anthony Lamb  62   4.0  19.3    6.7   0.9   2.6   3.5   1.5  0.5  0.3
# ...

# %%
Bucks = gen_dataframe("https://www.espn.com/nba/team/stats/_/name/mil/milwaukee-bucks")
Bucks
# Out:
#                       Name  GP    GS   MIN    PTS    OR    DR   REB   AST  \
# 0    Giannis Antetokounmpo  63  63.0  32.1   31.1   2.2   9.6  11.8   5.7
# 1             Jrue Holiday  67  65.0  32.6   19.3   1.2   3.9   5.1   7.4
# 2              Brook Lopez  78  78.0  30.4   15.9   2.0   4.7   6.7   1.3
# 3          Khris Middleton  33  19.0  24.3   15.1   0.8   3.4   4.2   4.9
# 4             Bobby Portis  70  22.0  26.0   14.1   2.2   7.4   9.6   1.5
# 5            Grayson Allen  72  70.0  27.4   10.4   0.8   2.4   3.3   2.3
# 6             Jevon Carter  81  39.0  22.4    8.0   0.4   2.1   2.5   2.4
# 7          Pat Connaughton  61  33.0  23.7    7.6   0.8   3.8   4.6   1.3
# 8        Lindell Wigginton   7   1.0  12.4    7.1   0.0   1.0   1.0   2.0
# 9               Joe Ingles  46   0.0  22.7    6.9   0.3   2.5   2.8   3.3
# 10             Jae Crowder  18   3.0  18.9    6.9   0.9   2.9   3.8   1.5
# 11            Jordan Nwora  38   3.0  15.7    6.0   0.8   2.3   3.1   1.0
# ...

# %%
Celtics = gen_dataframe("https://www.espn.com/nba/team/stats/_/name/bos/boston-celtics")
Celtics
# Out:
#                  Name  GP    GS   MIN    PTS   OR    DR   REB   AST  STL  BLK  \
# 0        Jayson Tatum  74  74.0  36.9   30.1  1.1   7.7   8.8   4.6  1.1  0.7
# 1        Jaylen Brown  67  67.0  35.9   26.6  1.2   5.7   6.9   3.5  1.1  0.4
# 2     Malcolm Brogdon  67   0.0  26.0   14.9  0.6   3.6   4.2   3.7  0.7  0.3
# 3       Derrick White  82  70.0  28.3   12.4  0.6   2.9   3.6   3.9  0.7  0.9
# 4        Marcus Smart  61  61.0  32.1   11.5  0.8   2.4   3.1   6.3  1.5  0.4
# 5          Al Horford  63  63.0  30.5    9.8  1.2   5.0   6.2   3.0  0.5  1.0
# 6      Grant Williams  79  23.0  25.9    8.1  1.1   3.5   4.6   1.7  0.5  0.4
# 7     Robert Williams  35  20.0  23.5    8.0  3.0   5.4   8.3   1.4  0.6  1.4
# 8          Sam Hauser  80   8.0  16.1    6.4  0.4   2.1   2.6   0.9  0.4  0.3
# 9        Mike Muscala  20   4.0  16.2    5.9  0.7   2.7   3.4   0.6  0.2  0.3
# 10   Payton Pritchard  48   3.0  13.4    5.6  0.5   1.3   1.8   1.3  0.3  0.0
# ...

# %%
Suns = gen_dataframe("https://www.espn.com/nba/team/stats/_/name/phx/phoenix-suns")
Suns
# Out:
#                 Name  GP    GS   MIN    PTS    OR    DR   REB   AST  STL  BLK  \
# 0       Devin Booker  53  53.0  34.6   27.8   0.9   3.7   4.5   5.5  1.0  0.3
# 1       Kevin Durant   8   8.0  33.6   26.0   0.4   6.0   6.4   3.5  0.3  1.3
# 2      Deandre Ayton  67  67.0  30.4   18.0   2.6   7.4  10.0   1.7  0.6  0.8
# 3      Mikal Bridges  56  56.0  36.4   17.2   1.0   3.3   4.3   3.6  1.2  0.8
# 4    Cameron Johnson  17  16.0  25.2   13.9   0.8   3.0   3.8   1.5  0.9  0.4
# 5         Chris Paul  59  59.0  32.0   13.9   0.5   3.8   4.3   8.9  1.5  0.4
# 6      Cameron Payne  48  15.0  20.2   10.3   0.3   2.0   2.2   4.5  0.7  0.2
# 7      Terrence Ross  21   0.0  18.4    9.0   0.6   2.7   3.3   2.0  0.5  0.1
# 8      Landry Shamet  40   9.0  20.2    8.7   0.3   1.4   1.7   2.3  0.7  0.1
# 9         Damion Lee  74   5.0  20.4    8.2   0.5   2.5   3.0   1.3  0.4  0.1
# 10  Duane Washington  31   3.0  12.7    7.9   0.1   1.1   1.2   2.0  0.2  0.1
# ...

# %%
def truncate(df):
    df = df[0:6]
    return df
Nuggets = truncate(Nuggets)
# Out:
#              Name  GP    GS   MIN   PTS   OR   DR   REB  AST  STL  BLK   TO  \
# 0    Nikola Jokic  69  69.0  33.7  24.5  2.4  9.4  11.8  9.8  1.3  0.7  3.6
# 1    Jamal Murray  65  65.0  32.8  20.0  0.7  3.2   4.0  6.2  1.0  0.2  2.2
# 2  Michael Porter  62  62.0  29.0  17.4  1.0  4.5   5.5  1.0  0.6  0.5  1.1
# 3    Aaron Gordon  68  68.0  30.2  16.3  2.4  4.1   6.6  3.0  0.8  0.8  1.4
# 4    Bones Hyland  42   1.0  19.5  12.1  0.2  1.8   2.0  3.0  0.7  0.3  1.6
# 5     Bruce Brown  80  31.0  28.5  11.5  0.8  3.3   4.1  3.4  1.1  0.6  1.5
#
#     PF  AST/TO  FGM   FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  2PM   2PA  \
# 0  2.5     2.7  9.4  14.8  63.2  0.8  2.2  38.3  4.9  6.0  82.2  8.5  12.7
# 1  1.6     2.8  7.3  16.0  45.4  2.6  6.6  39.8  2.8  3.3  83.3  4.6   9.4
# 2  1.9     1.0  6.4  13.2  48.7  3.0  7.3  41.4  1.5  1.9  80.0  3.4   5.9
# 3  1.9     2.1  6.3  11.2  56.4  0.9  2.5  34.7  2.8  4.6  60.8  5.4   8.6
# ...

# %%
Suns = truncate(Suns)
Bucks = truncate(Bucks)
Warriors = truncate(Warriors)
Celtics = truncate(Celtics)

# %%
teams = pd.concat([Nuggets,Suns,Bucks,Warriors,Celtics])
`teams
# Out:
#                     Name  GP    GS   MIN   PTS   OR   DR   REB  AST  STL  BLK  \
# 0           Nikola Jokic  69  69.0  33.7  24.5  2.4  9.4  11.8  9.8  1.3  0.7
# 1           Jamal Murray  65  65.0  32.8  20.0  0.7  3.2   4.0  6.2  1.0  0.2
# 2         Michael Porter  62  62.0  29.0  17.4  1.0  4.5   5.5  1.0  0.6  0.5
# 3           Aaron Gordon  68  68.0  30.2  16.3  2.4  4.1   6.6  3.0  0.8  0.8
# 4           Bones Hyland  42   1.0  19.5  12.1  0.2  1.8   2.0  3.0  0.7  0.3
# 5            Bruce Brown  80  31.0  28.5  11.5  0.8  3.3   4.1  3.4  1.1  0.6
# 0           Devin Booker  53  53.0  34.6  27.8  0.9  3.7   4.5  5.5  1.0  0.3
# 1           Kevin Durant   8   8.0  33.6  26.0  0.4  6.0   6.4  3.5  0.3  1.3
# 2          Deandre Ayton  67  67.0  30.4  18.0  2.6  7.4  10.0  1.7  0.6  0.8
# 3          Mikal Bridges  56  56.0  36.4  17.2  1.0  3.3   4.3  3.6  1.2  0.8
# 4        Cameron Johnson  17  16.0  25.2  13.9  0.8  3.0   3.8  1.5  0.9  0.4
# ...

# %%
#teams.to_excel("top_6.xlsx")
